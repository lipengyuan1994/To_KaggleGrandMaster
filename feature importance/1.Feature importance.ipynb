# %%
import pandas as pd
# pd.options.display.max_columns = None
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from matplotlib.pyplot import figure

# %%
figure(num=None, figsize=(12, 12), facecolor='w', edgecolor='k')

# %%
train  = pd.read_csv('data/train.csv')

# %%
train.head(10)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4    var_5  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621   3.5609
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355  -8.0198
# 7  train_7       0  13.5580 -7.9881  13.8776  7.5985   8.6543   0.8310
# 8  train_8       0  16.1071  2.4426  13.9307  5.6327   8.8014   6.1630
# 9  train_9       0  12.5088  1.9743   8.8960  5.4508  13.6043 -16.2859
#
#     var_6    var_7   var_8   var_9  var_10   var_11   var_12   var_13  \
# 0  5.1187  18.6266 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
desc = train.describe()
desc  =desc.reset_index( )
desc.head()
# Out:
#    index         target          var_0          var_1          var_2  \
# 0  count  200000.000000  200000.000000  200000.000000  200000.000000
# 1   mean       0.100490      10.679914      -1.627622      10.715192
# 2    std       0.300653       3.040051       4.050044       2.640894
# 3    min       0.000000       0.408400     -15.043400       2.117100
# 4    25%       0.000000       8.453850      -4.740025       8.722475
#
#            var_3          var_4          var_5          var_6          var_7  \
# 0  200000.000000  200000.000000  200000.000000  200000.000000  200000.000000
# 1       6.796529      11.078333      -5.065317       5.408949      16.545850
# 2       2.043319       1.623150       7.863267       0.866607       3.418076
# 3      -0.040200       5.074800     -32.562600       2.347300       5.349700
# 4       5.254075       9.883175     -11.200350       4.767700      13.943800
#
#            var_8          var_9         var_10         var_11         var_12  \
# ...

# %%
desc.index = desc.index.astype('str')

# %%
desc.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
desc[desc.loc[1,] == 1]
# Out:
# /Users/lipengyuan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-78-88e75a3c3571> in <module>
# ----> 1 desc[desc.loc[1,] == 1]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2965         # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
train.target.unique()
# Out:
# array([0, 1])

# %%
train[train.notnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %% [markdown]
# # Build a quick baseline

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a copy to work with
X = train.copy()

# Save and drop labels
y = train.target
X = X.drop('target', axis=1)



# Label encoder
for c in train.columns[train.dtypes == 'object']:
    X[c] = X[c].factorize()[0]
    
rf = RandomForestClassifier()
rf.fit(X,y)
# Out:
# /Users/lipengyuan/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
plt.plot(rf.feature_importances_)
plt.xticks(np.arange(X.shape[1]), X.columns.tolist(), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x162ca3198>,
# ...
#  <a list of 201 Text xticklabel objects>)

# %%
# figure(num=None, figsize=(20, 12), facecolor='w', edgecolor='k')
# plt.plot(rf.feature_importances_)
# plt.xticks(np.arange(X.shape[1]), X.columns.tolist(), rotation=90)

# %%
# figure(num=None, figsize=(30, 12), facecolor='w', edgecolor='k')
# plt.plot(rf.feature_importances_)
# plt.xticks(np.arange(X.shape[1]), X.columns.tolist(), rotation=90)

# %%
# figure(num=None, figsize=(60, 12), facecolor='w', edgecolor='k')
# plt.plot(rf.feature_importances_)
# plt.xticks(np.arange(X.shape[1]), X.columns.tolist(), rotation=90)

# %%
figure(num=None, figsize=(60, 12), facecolor='w', edgecolor='k')
plt.plot(rf.feature_importances_)
plt.xticks(np.arange(X.shape[1]), X.columns.tolist(), rotation=90)
plt.savefig('feature_importance.png')

# %% [markdown]
# There is something interesting about var_81

# %%
print ('Mean var_81:', train.var_81.mean())
print ('std:', train.var_81.std())
# Out:
# Mean: 14.719023858500014
# std: 2.299567114776461

# %%
# And we see that it has a lot of repeated values   ##var71 also have a lot repeated values
# (train.var_81.value_counts()>10).all()
train.var_81.value_counts()
# Out:
# 15.6210    14
# 15.8789    13
# 14.1672    13
# 15.0039    13
# 13.5828    13
# 15.9831    13
# 16.2902    13
# 14.2303    12
# 15.7141    12
# 15.0453    12
# 14.6781    12
# 15.7769    12
# 14.0392    12
# 14.0762    12
# 15.6586    12
# 14.9629    12
# 15.0753    12
# 15.5699    12
# 15.9957    12
# 14.5830    12
# 13.0561    11
# 15.3766    11
# 14.7686    11
# 16.4667    11
# 15.1089    11
# 15.7860    11
# 14.8328    11
# 14.2161    11
# 15.1064    11
# 14.5210    11
#            ..
# 9.3085      1
# 12.1153     1
# 9.5319      1
# 15.2520     1
# 19.2340     1
# 16.7821     1
# 11.6967     1
# 19.0822     1
# 16.9625     1
# 10.6111     1
# 10.5981     1
# 18.8730     1
# 17.7864     1
# 13.2327     1
# 16.9833     1
# 10.9824     1
# 14.7418     1
# 16.7128     1
# 9.0648      1
# 9.1227      1
# 18.9028     1
# 16.3127     1
# 18.5538     1
# 19.2569     1
# 11.8707     1
# 11.0443     1
# 10.4744     1
# 10.5579     1
# 18.7701     1
# 11.4696     1
# ...

# %%
 ##var71 also have a lot repeated values
# (train.var_71.value_counts()>10).all()
train.var_71.value_counts()
# Out:
#  0.7031    54
#  0.5283    44
#  0.7040    43
#  0.7548    43
#  0.7378    43
#  0.7663    42
#  0.6693    42
#  0.7523    42
#  0.6617    42
#  0.7570    41
#  0.5627    41
#  0.5898    41
#  0.6094    41
#  0.7211    41
#  0.5633    41
#  0.6261    40
#  0.6276    40
#  0.6153    40
#  0.6562    40
#  0.7037    40
#  0.7374    40
#  0.6151    39
#  0.7914    39
#  0.6600    39
#  0.7412    39
#  0.6246    39
#  0.7471    39
#  0.6292    39
#  0.6645    39
#  0.6933    39
#            ..
#  1.2749     1
#  1.3427     1
#  1.3031     1
#  1.3854     1
#  1.3225     1
#  1.2871     1
#  1.2684     1
# -0.0119     1
#  1.3215     1
#  0.0917     1
#  0.0028     1
#  1.3711     1
# -0.0271     1
#  1.2491     1
#  1.4269     1
#  1.2599     1
#  1.2566     1
#  1.3890     1
# -0.0625     1
#  1.3275     1
#  0.0521     1
#  0.0607     1
#  1.2041     1
#  0.1003     1
#  1.4528     1
#  0.0483     1
#  1.3575     1
#  0.0480     1
#  1.2890     1
#  1.3227     1
# ...

# %%
# It's very hard to work with scaled feature, so let's try to scale them back
# Let's first take a look at difference between neighbouring values in x8

v81_unique = train.var_81.unique()
v81_unique_sorted = np.sort(v81_unique)
                           
diff = pd.DataFrame(np.diff(v81_unique_sorted))

# %%
# diff.columns
diff[0].value_counts()
# Out:
# 0.0001    53023
# 0.0002     7558
# 0.0001     6395
# 0.0003     2115
# 0.0002     1623
# 0.0001     1488
# 0.0004      896
# 0.0001      837
# 0.0003      744
# 0.0002      530
# 0.0004      436
# 0.0005      364
# 0.0005      285
# 0.0003      255
# 0.0001      242
# 0.0006      194
# 0.0006      179
# 0.0004      156
# 0.0005      134
# 0.0007      118
# 0.0007       98
# 0.0007       86
# 0.0006       85
# 0.0008       74
# 0.0009       70
# 0.0008       65
# 0.0008       62
# 0.0011       54
# 0.0010       53
# 0.0002       48
#           ...
# 0.0034        1
# 0.0145        1
# 0.0073        1
# 0.0146        1
# 0.0199        1
# 0.0070        1
# 0.0095        1
# 0.0073        1
# 0.0132        1
# 0.0159        1
# 0.0090        1
# 0.0048        1
# 0.0307        1
# 0.0055        1
# 0.0064        1
# 0.0250        1
# 0.0775        1
# 0.0044        1
# 0.0184        1
# 0.0109        1
# 0.1058        1
# 0.0056        1
# 0.0109        1
# 0.0702        1
# ...

# %%
# The most of the diffs are 0.001 ! 
# The data is scaled, so we don't know what was the diff value for the original feature
# But let's assume it was 1.0
# Let's devide all the numbers by 0.001 to get the right scaling
# note, that feature will still have zero mean

np.diff(v81_unique_sorted/0.0001)
# Out:
# array([  73., 4034.,  217., ...,  702.,  596., 2024.])

# %%
v81_int = (train.var_81/0.0001 - 14/0.0001)

# %%
v81_int
# Out:
# 0         -1628.0
# 1         41782.0
# 2         17811.0
# 3        -34596.0
# 4         -6683.0
# 5         13766.0
# 6        -16889.0
# 7         -6686.0
# 8          8569.0
# 9         26244.0
# 10        11476.0
# 11         4600.0
# 12        58428.0
# 13       -18323.0
# 14         9304.0
# 15        13367.0
# 16       -43082.0
# 17        32389.0
# 18         7277.0
# 19        35206.0
# 20        10392.0
# 21        50543.0
# 22       -20590.0
# 23         1861.0
# 24        32719.0
# 25         7120.0
# 26         -280.0
# 27         2670.0
# 28        -6446.0
# 29        12648.0
#            ...
# 199970    19507.0
# 199971     8752.0
# 199972    46671.0
# 199973    58027.0
# 199974    44264.0
# 199975    36878.0
# 199976    45354.0
# 199977     2220.0
# 199978    -8478.0
# 199979   -18323.0
# 199980   -30482.0
# 199981    13759.0
# 199982    11338.0
# 199983     7983.0
# 199984    42239.0
# 199985    28027.0
# 199986    20686.0
# 199987    75484.0
# 199988    31202.0
# ...

# %%
v81_int.value_counts()
# Out:
#  16210.0    14
#  22902.0    13
#  18789.0    13
#  10039.0    13
#  1672.0     13
#  19831.0    13
# -4172.0     13
#  16586.0    12
#  15699.0    12
#  2303.0     12
#  10453.0    12
#  17769.0    12
#  10753.0    12
#  6781.0     12
#  392.0      12
#  5830.0     12
#  17141.0    12
#  19957.0    12
#  762.0      12
#  9629.0     12
#  12912.0    11
#  28652.0    11
#  11089.0    11
#  13766.0    11
#  18363.0    11
#  23220.0    11
#  19480.0    11
#  13963.0    11
#  7686.0     11
#  2161.0     11
#             ..
#  17227.0     1
# -29397.0     1
# -26689.0     1
# -26638.0     1
#  49580.0     1
# -45298.0     1
# -19484.0     1
#  18624.0     1
# -9632.0      1
# -28402.0     1
#  52652.0     1
#  49236.0     1
#  30257.0     1
#  32052.0     1
# -34185.0     1
#  75003.0     1
#  18727.0     1
# -29823.0     1
# -37763.0     1
#  24727.0     1
# -38155.0     1
# -43773.0     1
# -15295.0     1
#  12182.0     1
# -9633.0      1
# -21630.0     1
#  55734.0     1
# ...

# %%
# (v81_int + 1948).value_counts().sort_index()
